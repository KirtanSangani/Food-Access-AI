# %%
#import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#import dataset
df = pd.read_csv(r"C:\Users\kirta\OneDrive\Desktop\Projects\Food-Access-AI\Data\FoodAccessResearchAtlasData2019.xlsx - Food Access Research Atlas.csv")

#check for missing values
df.isnull().sum()

#print first 5 rows of dataset
print(df.shape)
print(df.head())

#describe dataset
print(df.describe())

df.hist(figsize = (30,20))
plt.show()
# Out:
# (67213, 62)
#      State          County  Urban  Pop2010  OHU2010  GroupQuartersFlag  \
# 0  Alabama  Autauga County      1     1912      693                  0
# 1  Alabama  Autauga County      1     2170      743                  0
# 2  Alabama  Autauga County      1     3373     1256                  0
# 3  Alabama  Autauga County      1     4386     1722                  0
# 4  Alabama  Autauga County      1    10766     4082                  0
#
#    NUMGQTRS  PCTGQTRS  LILATracts_1And10  LILATracts_halfAnd10  ...  \
# 0       0.0      0.00                  0                     0  ...
# 1     181.0      8.34                  1                     1  ...
# 2       0.0      0.00                  0                     0  ...
# 3       0.0      0.00                  0                     0  ...
# 4     181.0      1.68                  0                     0  ...
#
#    TractSeniors  TractWhite  TractBlack  TractAsian  TractNHOPI  TractAIAN  \
# ...

# %%
#create correlation heatmap
numerical_df = df.select_dtypes(include='number')
sns.heatmap(numerical_df.corr(), annot = True)
plt.show()

# %%
#Scatterplot of certain attributes which I believe should be compared
sns.scatterplot(x='PovertyRate', y= 'MedianFamilyIncome', data=df)
plt.show()
